# %%
import json
import requests
import pandas as pd
import numpy as np
import math
import csv

from pandas import DataFrame

# %%
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2NvdW50X2lkIjoiNTAzNDY4MjEzIiwiYXV0aF9pZCI6IjIiLCJ0b2tlbl90eXBlIjoiQWNjZXNzVG9rZW4iLCJzZXJ2aWNlX2lkIjoiNDMwMDExNDgxIiwiWC1BcHAtUmF0ZS1MaW1pdCI6IjIwMDAwOjEwIiwibmJmIjoxNTgxMDg0OTg5LCJleHAiOjE2NDQxNTY5ODksImlhdCI6MTU4MTA4NDk4OX0.tg1PMEcRjukDKo3SpCrbhXKQk82nIsKVXRv6LosKPro'

# %% [markdown]
# ## 매치 종류

# %%
match_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/matchtype.json')
match_parsed_data = match_url.json()
match_type = pd.DataFrame(match_parsed_data)

# %%
match_type.head()
# Out:
#    desc  matchtype
# 0  공식경기         50
# 1  감독모드         52

# %% [markdown]
# ## 선수 고유 식별자

# %%
spid_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/spid.json')
spid_parsed_data = spid_url.json()
spid = pd.DataFrame(spid_parsed_data)

# %%
spid.head()
# Out:
#           id       name
# 0  101000001    데이비드 시먼
# 1  101000195     로비 파울러
# 2  101000393     테디 셰링엄
# 3  101000805      옌스 레만
# 4  101001040  호베르투 카를루스

# %%
len(spid)
# Out:
# 34095

# %% [markdown]
# 게임에서 유저가 사용할 수 있는 선수의 수는 총 34095명이다. 선수는 ```id```로 관리된다.

# %% [markdown]
# ## 선수 포지션

# %%
spposition_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/spposition.json')
spposition_parsed_data = spposition_url.json()
spposition = pd.DataFrame(spposition_parsed_data)

# %%
spposition
# Out:
#    desc  spposition
# 0    GK           0
# 1    SW           1
# 2   RWB           2
# 3    RB           3
# 4   RCB           4
# 5    CB           5
# 6   LCB           6
# 7    LB           7
# 8   LWB           8
# 9   RDM           9
# 10  CDM          10
# 11  LDM          11
# 12   RM          12
# 13  RCM          13
# 14   CM          14
# 15  LCM          15
# 16   LM          16
# 17  RAM          17
# 18  CAM          18
# 19  LAM          19
# 20   RF          20
# 21   CF          21
# 22   LF          22
# 23   RW          23
# 24   RS          24
# 25   ST          25
# 26   LS          26
# 27   LW          27
# 28  SUB          28

# %% [markdown]
# 한 선수는 GK부터 SUB까지 총 29개의 포지션을 가질 수 있으며, 포지션은 ```spposition```으로 관리된다.

# %% [markdown]
# ## 시도한 방법 1

# %% [markdown]
# 기준을 <b>선수</b>로 하여, 선수 1명당 가질 수 있는 포지션의 경우를 모두 계산해 데이터프레임으로 저장한다.

# %%
a = ['a', 'b', 'c', 'd', 'e']
b = [1,2,3]

df = pd.DataFrame(columns = ['선수id', '포지션'])
for i in a :
    for j in b :
        df = df.append(pd.DataFrame([[i, j]], columns = ['선수id', '포지션']))

df
# Out:
#   선수id 포지션
# 0    a   1
# 0    a   2
# 0    a   3
# 0    b   1
# 0    b   2
# 0    b   3
# 0    c   1
# 0    c   2
# 0    c   3
# 0    d   1
# 0    d   2
# 0    d   3
# 0    e   1
# 0    e   2
# 0    e   3

# %%
df = pd.DataFrame(columns = ['id', 'po'])

for i in spid['id'] :
    for j in spposition['spposition'] :
        df = df.append(pd.DataFrame([[i, j]], columns = ['id', 'po']))

df

# %% [markdown]
# ### 문제 1
# 모든 선수들이 가질 수 있는 포지션의 경우의 수를 모두 데이터 프레임에 추가하려고 했는데, 실행 시간이 너무 오래 걸린다.

# %% [markdown]
# ### 해결 1

# %% [markdown]
# 선수들의 수를 10명씩 나누어서 데이터 프레임을 만든다.

# %%
def divide_list(l, n):
    for i in range(0, len(l), n) :
        yield l[i:i+n]

n = 10

spid_list = list(divide_list(spid['id'], n))

# %%
len(spid_list)
# Out:
# 3410

# %%
def df_maker(l) :
    df = pd.DataFrame(columns = ['id', 'po'])
    for i in spid_list[l] :
        for j in spposition['spposition'] :
            df = df.append(pd.DataFrame([[i, j]], columns = ['id', 'po']))

# %% [markdown]
# ### 문제 1-1
# 결국 실행해야 하는 반복문의 수가 너무 많다!

# %% [markdown]
# ## 해결법

# %%
position = list(spposition['spposition'])
player = list(spid['id'])

list_with_tuple = [(x,y) for x in position for y in player]

# %%
list_with_dic = [{"id": x, "po":y} for x in player for y in position]

# %% [markdown]
# ## API 조회하기
# TOP 10,000 랭커 유저가 사용한 선수의 20경기 평균 스탯을 조회합니다.
# 선수의 고유 식별자와 포지션의 목록으로 랭커 유저가 사용한 선수의 평균 스탯 기록을 조회할 수 있습니다.
# 한번에 너무 많은 선수목록을 입력할 경우 413 Request Entity Too Large 에러가 반환될 수 있습니다.
# 한번에 호출하는 선수의 수는 50명이 적당합니다.
#
# 조회하고자 하는 선수 목록을 다음과 같이 구성하여 {players} 파라미터로 전송하면 API를 조회할 수 있습니다 :
#
# {players} : "id", "po"필드를 가지고 있는 Json Object Array
# - id : 선수 고유 식별자 (spid, /metadata/spid API 참고)
# - po : 선수 포지션 (spposition, /metadata/spposition API 참고)
#
# ex) [{"id":101001183,"po":7}, {"id":214003647,"po":25},…]
#
# *데이터는 매일 3, 9, 15, 21시에 갱신을 시작하며 최대 한시간까지 소요될 수 있습니다.
# 갱신된 데이터는 갱신시작 시점을 기준으로 3시간 전 데이터까지 반영됩니다.

# %% [markdown]
# ### 시도 1

# %%
headers = {'Authorization' : api_key}

for i in range(int(math.ceil(len(list_with_dic)/29))) :
    r = requests.get("https://api.nexon.co.kr/fifaonline4/v1.0/rankers/status?matchtype=50&players="+str(list_with_dic[i:28+i]), headers = headers)
    ranker = pd.DataFrame(r.json())

# %% [markdown]
# 한번에 너무 많은 목록을 입력할 때 생기는 오류를 방지하기 위해 ```list_with_dic[i:28+i]``` 선수 1명씩 호출한다. ```list_with_dic```에는 선수 1명과 가능한 29개의 포지션이 선수 ```id``` 순서대로 저장되어 있다.

# %% [markdown]
# ### 문제 1
# 실행 시간이 너무 많이 걸린다. 그리고 새로운 값을 채워넣는 것이 아니라 새로운 값이 생기면 ```ranker```데이터프레임 내의 값들이 바뀌게 된다.

# %% [markdown]
# ### 시도 2
# 빈 데이터프레임을 만든 다음 json 값을 채워넣는다.

# %%
headers = {'Authorization' : api_key}
ranker = pd.DataFrame(columns=['createDate', 'spId', 'spPosition', 'status'])

for i in range(int(math.ceil(len(list_with_dic)/29))) :
    r = requests.get("https://api.nexon.co.kr/fifaonline4/v1.0/rankers/status?matchtype=50&players="+str(list_with_dic[i:28+i]), headers = headers)
    ranker = ranker.append(pd.DataFrame(r.json()))

# %% [markdown]
# ### 문제 2
# 그래도 실행시간이 너무 오래 걸린다.

# %% [markdown]
# ###############

# %% [markdown]
# 아래의 방식으로 전송하면 데이터프레임이 잘 나온다. 그런데 인덱스 값이 이상하다.

# %%
headers = {'Authorization' : api_key}
ranker = pd.DataFrame(columns=['createDate', 'spId', 'spPosition', 'status'])

for i in range(40) :
    r = requests.get("https://api.nexon.co.kr/fifaonline4/v1.0/rankers/status?matchtype=50&players="+str(list_with_dic[i:29+i]), headers = headers)
    ranker = ranker.append(pd.DataFrame(r.json()))

ranker
# Out:
#              createDate       spId spPosition  \
# 0   2020-02-24T02:30:00  101000001          0
# 1   2019-12-28T02:30:00  101000001         28
# 0   2019-12-28T02:30:00  101000001         28
# 0   2019-12-28T02:30:00  101000001         28
# 0   2019-12-28T02:30:00  101000001         28
# 0   2019-12-28T02:30:00  101000001         28
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 2   2020-02-19T02:30:00  101000195         12
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# 2   2020-02-19T02:30:00  101000195         12
# 0   2019-12-28T02:30:00  101000001         28
# 1   2020-02-26T02:30:00  101000195          4
# ..                  ...        ...        ...
# 2   2020-01-25T02:30:00  101000195         15
# 3   2020-02-22T02:30:00  101000195         16
# 4   2020-01-29T02:30:00  101000195         17
# 5   2020-02-26T02:30:00  101000195         18
# 6   2020-02-26T02:30:00  101000195         19
# 7   2020-02-06T02:30:00  101000195         20
# 8   2020-02-26T02:30:00  101000195         21
# 9   2020-02-24T02:30:00  101000195         22
# 10  2019-12-25T02:30:00  101000195         23
# 11  2020-02-24T02:30:00  101000195         24
# 12  2020-02-26T02:30:00  101000195         25
# 13  2020-02-26T02:30:00  101000195         26
# 14  2020-02-26T02:30:00  101000195         27
# 15  2020-02-26T02:30:00  101000195         28
# 0   2020-02-19T02:30:00  101000195         12
# 1   2020-02-09T02:30:00  101000195         14
# 2   2020-01-25T02:30:00  101000195         15
# 3   2020-02-22T02:30:00  101000195         16
# 4   2020-01-29T02:30:00  101000195         17
# 5   2020-02-26T02:30:00  101000195         18
# 6   2020-02-26T02:30:00  101000195         19
# 7   2020-02-06T02:30:00  101000195         20
# 8   2020-02-26T02:30:00  101000195         21
# 9   2020-02-24T02:30:00  101000195         22
# 10  2019-12-25T02:30:00  101000195         23
# 11  2020-02-24T02:30:00  101000195         24
# 12  2020-02-26T02:30:00  101000195         25
# 13  2020-02-26T02:30:00  101000195         26
# 14  2020-02-26T02:30:00  101000195         27
# 15  2020-02-26T02:30:00  101000195         28
#
#                                                status
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 2   {'shoot': 2.0, 'effectiveShoot': 2.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 2   {'shoot': 2.0, 'effectiveShoot': 2.0, 'assist'...
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# ..                                                ...
# 2   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 3   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 4   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 5   {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 6   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 7   {'shoot': 1.0, 'effectiveShoot': 1.0, 'assist'...
# 8   {'shoot': 1.6, 'effectiveShoot': 1.5, 'assist'...
# 9   {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 10  {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 11  {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 12  {'shoot': 1.9, 'effectiveShoot': 1.6, 'assist'...
# 13  {'shoot': 2.28571, 'effectiveShoot': 2.0, 'ass...
# 14  {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 15  {'shoot': 0.35, 'effectiveShoot': 0.35, 'assis...
# 0   {'shoot': 2.0, 'effectiveShoot': 2.0, 'assist'...
# 1   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 2   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 3   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 4   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 5   {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 6   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 7   {'shoot': 1.0, 'effectiveShoot': 1.0, 'assist'...
# 8   {'shoot': 1.6, 'effectiveShoot': 1.5, 'assist'...
# 9   {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 10  {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 11  {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 12  {'shoot': 1.9, 'effectiveShoot': 1.6, 'assist'...
# 13  {'shoot': 2.28571, 'effectiveShoot': 2.0, 'ass...
# 14  {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 15  {'shoot': 0.35, 'effectiveShoot': 0.35, 'assis...
#
# [356 rows x 4 columns]

# %%
headers = {'Authorization' : api_key}

for i in range(30) :
        r = requests.get("https://api.nexon.co.kr/fifaonline4/v1.0/rankers/status?matchtype=50&players="+str(list_with_dic[i:29+i]), headers = headers)
        ranker = pd.DataFrame(r.json())

ranker
# Out:
#              createDate       spId  spPosition  \
# 0   2020-02-26T02:30:00  101000195           4
# 1   2020-02-19T02:30:00  101000195          12
# 2   2020-02-09T02:30:00  101000195          14
# 3   2020-01-25T02:30:00  101000195          15
# 4   2020-02-22T02:30:00  101000195          16
# 5   2020-01-29T02:30:00  101000195          17
# 6   2020-02-26T02:30:00  101000195          18
# 7   2020-02-26T02:30:00  101000195          19
# 8   2020-02-06T02:30:00  101000195          20
# 9   2020-02-26T02:30:00  101000195          21
# 10  2020-02-24T02:30:00  101000195          22
# 11  2019-12-25T02:30:00  101000195          23
# 12  2020-02-24T02:30:00  101000195          24
# 13  2020-02-26T02:30:00  101000195          25
# 14  2020-02-26T02:30:00  101000195          26
# 15  2020-02-26T02:30:00  101000195          27
# 16  2020-02-26T02:30:00  101000195          28
#
#                                                status
# 0   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 1   {'shoot': 2.0, 'effectiveShoot': 2.0, 'assist'...
# 2   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 3   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 4   {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 5   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 6   {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 7   {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 8   {'shoot': 1.0, 'effectiveShoot': 1.0, 'assist'...
# 9   {'shoot': 1.6, 'effectiveShoot': 1.5, 'assist'...
# 10  {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 11  {'shoot': 0.0, 'effectiveShoot': 0.0, 'assist'...
# 12  {'shoot': 2.0, 'effectiveShoot': 1.0, 'assist'...
# 13  {'shoot': 1.9, 'effectiveShoot': 1.6, 'assist'...
# 14  {'shoot': 2.28571, 'effectiveShoot': 2.0, 'ass...
# 15  {'shoot': 0.5, 'effectiveShoot': 0.5, 'assist'...
# 16  {'shoot': 0.35, 'effectiveShoot': 0.35, 'assis...

# %% [markdown]
# ### 시도 3

# %% [markdown]
# 데이터를 데이터프레임 형태 말고 csv 파일 형태로 저장해 보자.

# %%
import csv

open('ranker_output.csv', 'w', newline ='')
f = open('ranker_output.csv', 'a', newline = '')
writer = csv.writer(f)

try :
    for i in range(int(math.ceil(len(list_with_dic)/29))) :
        r = requests.get("https://api.nexon.co.kr/fifaonline4/v1.0/rankers/status?matchtype=50&players="+str(list_with_dic[i:29+i]), headers = headers)
        writer.writerow(r)
    f.close()
    
except :
    print("ERROR")

# %% [markdown]
# 그래도 for문을 돌리면 실행 시간이 너무 길다. csv 파일의 문제가 아닌 걸까.

# %% [markdown]
# http://hleecaster.com/python-how-to-split-a-list-into-chunks/
# https://programmers.co.kr/learn/courses/4008/lessons/12738
# https://specialmylife.tistory.com/entry/pandas-DataFrame-%EC%82%AC%EC%9A%A9%EB%B2%95-%EC%A0%95%EB%A6%AC%EC%9E%91%EC%97%85%EC%A4%91
# https://da-nika.tistory.com/14
# https://devpouch.tistory.com/55
